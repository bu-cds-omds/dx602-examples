# %% [markdown]
# Reading Text Files

# %%
# sample text file
filename = 'time.txt'

# %% [markdown]
# Reading a TSV (tab separated values) structured file

# %%
# sample TSV file: 
filename = 'data6_c.tsv'

# %% [markdown]
# Reading a CSV (comma-separated-values) structured file

# %%
# sample CSV file
filename = 'data6_d.csv'

# %% [markdown]
# JSON Example:

# %%
# sample json file
filename = 'data6_e.json'
