# %% [markdown]
# # Code Example: Making Bar Charts
#
# The following example code will show you how to make bar charts in Matplotlib.
# Bar charts are useful for showing volume, and volume breakdowns, but require a little extra work to stack the bars.

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]
daily_mangos = [3, 1, 1, 4, 5, 6, 7]

plt.bar(days, daily_mangos, label="mangos")
plt.legend()
plt.title("Daily Fruit Consumption")
None

# %% [markdown]
# **Code Notes:**
# * The [Matplotlib function `matplotlib.pyplot.bar`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar), referenced as `plt.bar`, creates bar charts similarly to `plot`.
#   * However, one of these similar elements is that new plots are drawn on top of the previous plots.
#   * To get properly stacked bar charts, later plots need to pass in a `bottom` parameter with the cumulative sum of the previous bar chart sizes.

# %%
daily_papayas = [1, 1, 0, 3, 2, 1, 0]

plt.bar(days, daily_mangos, label="mangos")
plt.bar(days, daily_papayas, label="papayas", bottom=daily_mangos)
plt.legend()
plt.title("Daily Fruit Consumption")
None

# %% [markdown]
# **Code Notes:**
# * Re: the `bottom` argument,
#   * Setting the bottom argument is not a lot of work if there is just one previous label.
#   * If there is more than one previous label, you will have to keep track of the cumulative totals.
#   * The stacked bar chart example gives sample code from the Matplotlib team.
