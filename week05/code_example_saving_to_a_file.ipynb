# %% [markdown]
# # Code Example: Saving to a File

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]
daily_mangos = [3, 1, 1, 4, 5, 6, 7]

plt.bar(days, daily_mangos, label="mangos")
plt.legend()
plt.title("Daily Fruit Consumption")
plt.savefig("fruit.png")

# %% [markdown]
# **Code Notes:**
# * The [Matplotlib function `matplotlib.pyplot.savefig`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html), referenced as `plt.savefig`, will save the current figure to a filename.
#   * As long as the filename has a recognized extension (e.g. ".png"), it will automatically figure out the format that you want.
#   * There is an optional `format` argument, but we do not particularly recommend using it, as it suggests that your filename does not have an extension, or the extension does not match your chosen format. Either case will be confusing to whoever will be using your saved image files.
