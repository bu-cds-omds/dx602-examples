# %% [markdown]
# # Video: Organizing Your Data with Dictionaries and Lists
#
# This video gives an example of how to represent data using lists and dictionaries.

# %%
# !wget -O penguins.csv "https://portal.edirepository.org/nis/dataviewer?packageid=knb-lter-pal.219.3&entityid=002f3893385f710df69eeebe893144ff"
# Out:
# --2024-06-27 16:32:19--  https://portal.edirepository.org/nis/dataviewer?packageid=knb-lter-pal.219.3&entityid=002f3893385f710df69eeebe893144ff
# Resolving portal.edirepository.org (portal.edirepository.org)... 129.24.240.161
# Connecting to portal.edirepository.org (portal.edirepository.org)|129.24.240.161|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 23755 (23K) [text/csv]
# Saving to: ‘penguins.csv’
#
# penguins.csv        100%[===================>]  23.20K  --.-KB/s    in 0.04s
#
# 2024-06-27 16:32:20 (656 KB/s) - ‘penguins.csv’ saved [23755/23755]

# %%
import csv

with open("penguins.csv") as fp:
    reader = csv.DictReader(fp)
    data = [r for r in reader]

data[0]
# Out:
# {'studyName': 'PAL0708',
#  'Sample Number': '1',
#  'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#  'Region': 'Anvers',
#  'Island': 'Torgersen',
#  'Stage': 'Adult, 1 Egg Stage',
#  'Individual ID': 'N1A1',
#  'Clutch Completion': 'Yes',
#  'Date Egg': '2007-11-11',
#  'Culmen Length (mm)': '39.1',
#  'Culmen Depth (mm)': '18.7',
#  'Flipper Length (mm)': '181',
#  'Body Mass (g)': '3750',
#  'Sex': 'MALE',
#  'Delta 15 N (o/oo)': '',
#  'Delta 13 C (o/oo)': '',
#  'Comments': 'Not enough blood for isotopes.'}

# %%
data[:10]
# Out:
# [{'studyName': 'PAL0708',
#   'Sample Number': '1',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N1A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-11',
#   'Culmen Length (mm)': '39.1',
#   'Culmen Depth (mm)': '18.7',
#   'Flipper Length (mm)': '181',
#   'Body Mass (g)': '3750',
#   'Sex': 'MALE',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'Not enough blood for isotopes.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '2',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N1A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-11',
#   'Culmen Length (mm)': '39.5',
#   'Culmen Depth (mm)': '17.4',
#   'Flipper Length (mm)': '186',
#   'Body Mass (g)': '3800',
#   'Sex': 'FEMALE',
#   'Delta 15 N (o/oo)': '8.94956',
#   'Delta 13 C (o/oo)': '-24.69454',
#   'Comments': ''},
#  {'studyName': 'PAL0708',
#   'Sample Number': '3',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N2A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-16',
#   'Culmen Length (mm)': '40.3',
#   'Culmen Depth (mm)': '18.0',
#   'Flipper Length (mm)': '195',
#   'Body Mass (g)': '3250',
#   'Sex': 'FEMALE',
#   'Delta 15 N (o/oo)': '8.36821',
#   'Delta 13 C (o/oo)': '-25.33302',
#   'Comments': ''},
#  {'studyName': 'PAL0708',
#   'Sample Number': '4',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N2A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-16',
#   'Culmen Length (mm)': '',
#   'Culmen Depth (mm)': '',
#   'Flipper Length (mm)': '',
#   'Body Mass (g)': '',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'Adult not sampled.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '5',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N3A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-16',
#   'Culmen Length (mm)': '36.7',
#   'Culmen Depth (mm)': '19.3',
#   'Flipper Length (mm)': '193',
#   'Body Mass (g)': '3450',
#   'Sex': 'FEMALE',
#   'Delta 15 N (o/oo)': '8.76651',
#   'Delta 13 C (o/oo)': '-25.32426',
#   'Comments': ''},
#  {'studyName': 'PAL0708',
#   'Sample Number': '6',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N3A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-16',
#   'Culmen Length (mm)': '39.3',
#   'Culmen Depth (mm)': '20.6',
#   'Flipper Length (mm)': '190',
#   'Body Mass (g)': '3650',
#   'Sex': 'MALE',
#   'Delta 15 N (o/oo)': '8.66496',
#   'Delta 13 C (o/oo)': '-25.29805',
#   'Comments': ''},
#  {'studyName': 'PAL0708',
#   'Sample Number': '7',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N4A1',
#   'Clutch Completion': 'No',
#   'Date Egg': '2007-11-15',
#   'Culmen Length (mm)': '38.9',
#   'Culmen Depth (mm)': '17.8',
#   'Flipper Length (mm)': '181',
#   'Body Mass (g)': '3625',
#   'Sex': 'FEMALE',
#   'Delta 15 N (o/oo)': '9.18718',
#   'Delta 13 C (o/oo)': '-25.21799',
#   'Comments': 'Nest never observed with full clutch.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '8',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N4A2',
#   'Clutch Completion': 'No',
#   'Date Egg': '2007-11-15',
#   'Culmen Length (mm)': '39.2',
#   'Culmen Depth (mm)': '19.6',
#   'Flipper Length (mm)': '195',
#   'Body Mass (g)': '4675',
#   'Sex': 'MALE',
#   'Delta 15 N (o/oo)': '9.46060',
#   'Delta 13 C (o/oo)': '-24.89958',
#   'Comments': 'Nest never observed with full clutch.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '9',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N5A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-09',
#   'Culmen Length (mm)': '34.1',
#   'Culmen Depth (mm)': '18.1',
#   'Flipper Length (mm)': '193',
#   'Body Mass (g)': '3475',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'No blood sample obtained.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '10',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N5A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-09',
#   'Culmen Length (mm)': '42.0',
#   'Culmen Depth (mm)': '20.2',
#   'Flipper Length (mm)': '190',
#   'Body Mass (g)': '4250',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '9.13362',
#   'Delta 13 C (o/oo)': '-25.09368',
#   'Comments': 'No blood sample obtained for sexing.'}]

# %%
data[8]
# Out:
# {'studyName': 'PAL0708',
#  'Sample Number': '9',
#  'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#  'Region': 'Anvers',
#  'Island': 'Torgersen',
#  'Stage': 'Adult, 1 Egg Stage',
#  'Individual ID': 'N5A1',
#  'Clutch Completion': 'Yes',
#  'Date Egg': '2007-11-09',
#  'Culmen Length (mm)': '34.1',
#  'Culmen Depth (mm)': '18.1',
#  'Flipper Length (mm)': '193',
#  'Body Mass (g)': '3475',
#  'Sex': '',
#  'Delta 15 N (o/oo)': '',
#  'Delta 13 C (o/oo)': '',
#  'Comments': 'No blood sample obtained.'}

# %%
[r for r in data if r["Sex"] == ""]
# Out:
# [{'studyName': 'PAL0708',
#   'Sample Number': '4',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N2A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-16',
#   'Culmen Length (mm)': '',
#   'Culmen Depth (mm)': '',
#   'Flipper Length (mm)': '',
#   'Body Mass (g)': '',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'Adult not sampled.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '9',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N5A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-09',
#   'Culmen Length (mm)': '34.1',
#   'Culmen Depth (mm)': '18.1',
#   'Flipper Length (mm)': '193',
#   'Body Mass (g)': '3475',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'No blood sample obtained.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '10',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N5A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-09',
#   'Culmen Length (mm)': '42.0',
#   'Culmen Depth (mm)': '20.2',
#   'Flipper Length (mm)': '190',
#   'Body Mass (g)': '4250',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '9.13362',
#   'Delta 13 C (o/oo)': '-25.09368',
#   'Comments': 'No blood sample obtained for sexing.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '11',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N6A1',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-09',
#   'Culmen Length (mm)': '37.8',
#   'Culmen Depth (mm)': '17.1',
#   'Flipper Length (mm)': '186',
#   'Body Mass (g)': '3300',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '8.63243',
#   'Delta 13 C (o/oo)': '-25.21315',
#   'Comments': 'No blood sample obtained for sexing.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '12',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Torgersen',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N6A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-09',
#   'Culmen Length (mm)': '37.8',
#   'Culmen Depth (mm)': '17.3',
#   'Flipper Length (mm)': '180',
#   'Body Mass (g)': '3700',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'No blood sample obtained.'},
#  {'studyName': 'PAL0708',
#   'Sample Number': '48',
#   'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#   'Region': 'Anvers',
#   'Island': 'Dream',
#   'Stage': 'Adult, 1 Egg Stage',
#   'Individual ID': 'N29A2',
#   'Clutch Completion': 'Yes',
#   'Date Egg': '2007-11-13',
#   'Culmen Length (mm)': '37.5',
#   'Culmen Depth (mm)': '18.9',
#   'Flipper Length (mm)': '179',
#   'Body Mass (g)': '2975',
#   'Sex': '',
#   'Delta 15 N (o/oo)': '',
#   'Delta 13 C (o/oo)': '',
#   'Comments': 'Sexing primers did not amplify. Not enough blood for isotopes.'}]

# %%
[r["Comments"] for r in data if r["Sex"] == ""]
# Out:
# ['Adult not sampled.',
#  'No blood sample obtained.',
#  'No blood sample obtained for sexing.',
#  'No blood sample obtained for sexing.',
#  'No blood sample obtained.',
#  'Sexing primers did not amplify. Not enough blood for isotopes.']

# %%
set(r["Sex"] for r in data)
# Out:
# {'', 'FEMALE', 'MALE'}

# %%
data_by_sex = {}

# %%
for row in data:
    data_by_sex.setdefault(row["Sex"], []).append(row)

# %%
data_by_sex
# Out:
# {'MALE': [{'studyName': 'PAL0708',
#    'Sample Number': '1',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N1A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-11',
#    'Culmen Length (mm)': '39.1',
#    'Culmen Depth (mm)': '18.7',
#    'Flipper Length (mm)': '181',
#    'Body Mass (g)': '3750',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '6',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N3A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '39.3',
#    'Culmen Depth (mm)': '20.6',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3650',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.66496',
#    'Delta 13 C (o/oo)': '-25.29805',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '8',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N4A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2007-11-15',
#    'Culmen Length (mm)': '39.2',
#    'Culmen Depth (mm)': '19.6',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '4675',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.46060',
#    'Delta 13 C (o/oo)': '-24.89958',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '14',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N7A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-15',
#    'Culmen Length (mm)': '38.6',
#    'Culmen Depth (mm)': '21.2',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '3800',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '15',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N8A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '34.6',
#    'Culmen Depth (mm)': '21.1',
#    'Flipper Length (mm)': '198',
#    'Body Mass (g)': '4400',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.55583',
#    'Delta 13 C (o/oo)': '-25.22588',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '18',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N9A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '42.5',
#    'Culmen Depth (mm)': '20.7',
#    'Flipper Length (mm)': '197',
#    'Body Mass (g)': '4500',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.67538',
#    'Delta 13 C (o/oo)': '-25.13993',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '20',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N10A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '46.0',
#    'Culmen Depth (mm)': '21.5',
#    'Flipper Length (mm)': '194',
#    'Body Mass (g)': '4200',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.11616',
#    'Delta 13 C (o/oo)': '-24.77227',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '22',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N11A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '37.7',
#    'Culmen Depth (mm)': '18.7',
#    'Flipper Length (mm)': '180',
#    'Body Mass (g)': '3600',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.66271',
#    'Delta 13 C (o/oo)': '-25.06390',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '24',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N12A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '38.2',
#    'Culmen Depth (mm)': '18.1',
#    'Flipper Length (mm)': '185',
#    'Body Mass (g)': '3950',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.43423',
#    'Delta 13 C (o/oo)': '-25.22664',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '25',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N13A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-10',
#    'Culmen Length (mm)': '38.8',
#    'Culmen Depth (mm)': '17.2',
#    'Flipper Length (mm)': '180',
#    'Body Mass (g)': '3800',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.63954',
#    'Delta 13 C (o/oo)': '-25.29856',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '27',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N17A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '40.6',
#    'Culmen Depth (mm)': '18.6',
#    'Flipper Length (mm)': '183',
#    'Body Mass (g)': '3550',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.93997',
#    'Delta 13 C (o/oo)': '-25.36288',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '30',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N18A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2007-11-10',
#    'Culmen Length (mm)': '40.5',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '180',
#    'Body Mass (g)': '3950',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.90027',
#    'Delta 13 C (o/oo)': '-25.11609',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '32',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N21A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '37.2',
#    'Culmen Depth (mm)': '18.1',
#    'Flipper Length (mm)': '178',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.72764',
#    'Delta 13 C (o/oo)': '-25.01020',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '34',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N22A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '40.9',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '184',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.79665',
#    'Delta 13 C (o/oo)': '-25.14591',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '36',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N23A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '39.2',
#    'Culmen Depth (mm)': '21.1',
#    'Flipper Length (mm)': '196',
#    'Body Mass (g)': '4150',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.15308',
#    'Delta 13 C (o/oo)': '-25.03469',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '37',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N24A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '38.8',
#    'Culmen Depth (mm)': '20.0',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3950',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.18985',
#    'Delta 13 C (o/oo)': '-25.12255',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '40',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N25A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2007-11-13',
#    'Culmen Length (mm)': '39.8',
#    'Culmen Depth (mm)': '19.1',
#    'Flipper Length (mm)': '184',
#    'Body Mass (g)': '4650',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Nest never observed with full clutch. Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '42',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N26A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '40.8',
#    'Culmen Depth (mm)': '18.4',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '44',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N27A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-19',
#    'Culmen Length (mm)': '44.1',
#    'Culmen Depth (mm)': '19.7',
#    'Flipper Length (mm)': '196',
#    'Body Mass (g)': '4400',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.23720',
#    'Delta 13 C (o/oo)': '-24.52698',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '46',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N28A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '39.6',
#    'Culmen Depth (mm)': '18.8',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '4600',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.49106',
#    'Delta 13 C (o/oo)': '-24.10255',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '47',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N29A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-13',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '19.0',
#    'Flipper Length (mm)': '182',
#    'Body Mass (g)': '3425',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '50',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N30A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-13',
#    'Culmen Length (mm)': '42.3',
#    'Culmen Depth (mm)': '21.2',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '4150',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.87988',
#    'Delta 13 C (o/oo)': '-25.18543',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '52',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N21A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-06',
#    'Culmen Length (mm)': '40.1',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '188',
#    'Body Mass (g)': '4300',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.51362',
#    'Delta 13 C (o/oo)': '-26.55602',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '54',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N22A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-09',
#    'Culmen Length (mm)': '42.0',
#    'Culmen Depth (mm)': '19.5',
#    'Flipper Length (mm)': '200',
#    'Body Mass (g)': '4050',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.48095',
#    'Delta 13 C (o/oo)': '-26.31460',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '56',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N23A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-09',
#    'Culmen Length (mm)': '41.4',
#    'Culmen Depth (mm)': '18.6',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '3700',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.35396',
#    'Delta 13 C (o/oo)': '-26.27853',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '58',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N24A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-15',
#    'Culmen Length (mm)': '40.6',
#    'Culmen Depth (mm)': '18.8',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3800',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.56674',
#    'Delta 13 C (o/oo)': '-25.98843',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '60',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N25A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-15',
#    'Culmen Length (mm)': '37.6',
#    'Culmen Depth (mm)': '19.1',
#    'Flipper Length (mm)': '194',
#    'Body Mass (g)': '3750',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.10800',
#    'Delta 13 C (o/oo)': '-25.89677',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '62',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N27A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-13',
#    'Culmen Length (mm)': '41.3',
#    'Culmen Depth (mm)': '21.1',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '4400',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.74802',
#    'Delta 13 C (o/oo)': '-26.37809',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '64',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N28A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-13',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '18.2',
#    'Flipper Length (mm)': '192',
#    'Body Mass (g)': '4050',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.62264',
#    'Delta 13 C (o/oo)': '-26.60023',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '66',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N29A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-13',
#    'Culmen Length (mm)': '41.6',
#    'Culmen Depth (mm)': '18.0',
#    'Flipper Length (mm)': '192',
#    'Body Mass (g)': '3950',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.85562',
#    'Delta 13 C (o/oo)': '-26.09294',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '68',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N30A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-06',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '19.1',
#    'Flipper Length (mm)': '188',
#    'Body Mass (g)': '4100',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.71078',
#    'Delta 13 C (o/oo)': '-25.81012',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '70',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N32A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2008-11-11',
#    'Culmen Length (mm)': '41.8',
#    'Culmen Depth (mm)': '19.4',
#    'Flipper Length (mm)': '198',
#    'Body Mass (g)': '4450',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.86853',
#    'Delta 13 C (o/oo)': '-26.06209',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0809',
#    'Sample Number': '72',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N34A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-14',
#    'Culmen Length (mm)': '39.7',
#    'Culmen Depth (mm)': '18.4',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.29808',
#    'Delta 13 C (o/oo)': '-25.23453',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '74',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N35A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-11',
#    'Culmen Length (mm)': '45.8',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '197',
#    'Body Mass (g)': '4150',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.18658',
#    'Delta 13 C (o/oo)': '-26.45978',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '76',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N36A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-08',
#    'Culmen Length (mm)': '42.8',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '4250',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.29930',
#    'Delta 13 C (o/oo)': '-26.38986',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '78',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N37A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-06',
#    'Culmen Length (mm)': '37.2',
#    'Culmen Depth (mm)': '19.4',
#    'Flipper Length (mm)': '184',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.35540',
#    'Delta 13 C (o/oo)': '-26.44787',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '80',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N38A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-09',
#    'Culmen Length (mm)': '42.1',
#    'Culmen Depth (mm)': '19.1',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '4000',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.05736',
#    'Delta 13 C (o/oo)': '-25.81513',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '82',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N39A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-02',
#    'Culmen Length (mm)': '42.9',
#    'Culmen Depth (mm)': '17.6',
#    'Flipper Length (mm)': '196',
#    'Body Mass (g)': '4700',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.63259',
#    'Delta 13 C (o/oo)': '-26.23027',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '84',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N40A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-07',
#    'Culmen Length (mm)': '35.1',
#    'Culmen Depth (mm)': '19.4',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '4200',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.90002',
#    'Delta 13 C (o/oo)': '-26.46254',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '86',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N41A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-17',
#    'Culmen Length (mm)': '41.3',
#    'Culmen Depth (mm)': '20.3',
#    'Flipper Length (mm)': '194',
#    'Body Mass (g)': '3550',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.14863',
#    'Delta 13 C (o/oo)': '-26.09635',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '87',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N42A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-08',
#    'Culmen Length (mm)': '36.3',
#    'Culmen Depth (mm)': '19.5',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3800',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.57087',
#    'Delta 13 C (o/oo)': '-26.22227',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '89',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N44A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-08',
#    'Culmen Length (mm)': '38.3',
#    'Culmen Depth (mm)': '19.2',
#    'Flipper Length (mm)': '189',
#    'Body Mass (g)': '3950',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.07826',
#    'Delta 13 C (o/oo)': '-26.12417',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '92',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N45A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-14',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '18.1',
#    'Flipper Length (mm)': '205',
#    'Body Mass (g)': '4300',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.77018',
#    'Delta 13 C (o/oo)': '-25.83352',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '94',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N46A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-05',
#    'Culmen Length (mm)': '39.6',
#    'Culmen Depth (mm)': '18.1',
#    'Flipper Length (mm)': '186',
#    'Body Mass (g)': '4450',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.49915',
#    'Delta 13 C (o/oo)': '-26.42406',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '96',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N48A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-17',
#    'Culmen Length (mm)': '40.8',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '208',
#    'Body Mass (g)': '4300',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.48204',
#    'Delta 13 C (o/oo)': '-26.57941',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '98',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N49A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-08',
#    'Culmen Length (mm)': '40.3',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '196',
#    'Body Mass (g)': '4350',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.39459',
#    'Delta 13 C (o/oo)': '-26.01152',
#    'Comments': ''},
#   {'studyName': 'PAL0809',
#    'Sample Number': '100',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N50A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2008-11-10',
#    'Culmen Length (mm)': '43.2',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '192',
#    'Body Mass (g)': '4100',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.97025',
#    'Delta 13 C (o/oo)': '-26.03679',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '102',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N47A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-09',
#    'Culmen Length (mm)': '41.0',
#    'Culmen Depth (mm)': '20.0',
#    'Flipper Length (mm)': '203',
#    'Body Mass (g)': '4725',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.01079',
#    'Delta 13 C (o/oo)': '-26.38085',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '104',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N49A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '37.8',
#    'Culmen Depth (mm)': '20.0',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '4250',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.51929',
#    'Delta 13 C (o/oo)': '-25.69199',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '106',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N51A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '39.7',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '184',
#    'Body Mass (g)': '3550',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.85699',
#    'Delta 13 C (o/oo)': '-25.80208',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '108',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N53A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '38.2',
#    'Culmen Depth (mm)': '20.0',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.59245',
#    'Delta 13 C (o/oo)': '-25.70711',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '110',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N55A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-20',
#    'Culmen Length (mm)': '43.2',
#    'Culmen Depth (mm)': '19.0',
#    'Flipper Length (mm)': '197',
#    'Body Mass (g)': '4775',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.31735',
#    'Delta 13 C (o/oo)': '-25.45171',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '112',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N58A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-12',
#    'Culmen Length (mm)': '45.6',
#    'Culmen Depth (mm)': '20.3',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '4600',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.65466',
#    'Delta 13 C (o/oo)': '-26.32909',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '114',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N60A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '42.2',
#    'Culmen Depth (mm)': '19.5',
#    'Flipper Length (mm)': '197',
#    'Body Mass (g)': '4275',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.80186',
#    'Delta 13 C (o/oo)': '-26.41218',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '116',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N61A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '42.7',
#    'Culmen Depth (mm)': '18.3',
#    'Flipper Length (mm)': '196',
#    'Body Mass (g)': '4075',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.91434',
#    'Delta 13 C (o/oo)': '-26.42018',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '118',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N63A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-18',
#    'Culmen Length (mm)': '37.3',
#    'Culmen Depth (mm)': '20.5',
#    'Flipper Length (mm)': '199',
#    'Body Mass (g)': '3775',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.49645',
#    'Delta 13 C (o/oo)': '-26.36678',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '120',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N64A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-22',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '18.6',
#    'Flipper Length (mm)': '189',
#    'Body Mass (g)': '3325',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.32277',
#    'Delta 13 C (o/oo)': '-26.09989',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '122',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N66A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '37.7',
#    'Culmen Depth (mm)': '19.8',
#    'Flipper Length (mm)': '198',
#    'Body Mass (g)': '3500',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.11066',
#    'Delta 13 C (o/oo)': '-26.42563',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0910',
#    'Sample Number': '124',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N67A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '41.4',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '202',
#    'Body Mass (g)': '3875',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.59462',
#    'Delta 13 C (o/oo)': '-25.42621',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '126',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N69A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-18',
#    'Culmen Length (mm)': '40.6',
#    'Culmen Depth (mm)': '19.0',
#    'Flipper Length (mm)': '199',
#    'Body Mass (g)': '4000',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.22537',
#    'Delta 13 C (o/oo)': '-25.60826',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '128',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N71A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-21',
#    'Culmen Length (mm)': '41.5',
#    'Culmen Depth (mm)': '18.3',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '4300',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.52566',
#    'Delta 13 C (o/oo)': '-26.02450',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '130',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N72A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-18',
#    'Culmen Length (mm)': '44.1',
#    'Culmen Depth (mm)': '18.0',
#    'Flipper Length (mm)': '210',
#    'Body Mass (g)': '4000',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.10702',
#    'Delta 13 C (o/oo)': '-26.01363',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '132',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N73A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2009-11-23',
#    'Culmen Length (mm)': '43.1',
#    'Culmen Depth (mm)': '19.2',
#    'Flipper Length (mm)': '197',
#    'Body Mass (g)': '3500',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.86495',
#    'Delta 13 C (o/oo)': '-26.13960',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0910',
#    'Sample Number': '134',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N76A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-10',
#    'Culmen Length (mm)': '37.5',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '199',
#    'Body Mass (g)': '4475',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.56708',
#    'Delta 13 C (o/oo)': '-26.49288',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '136',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N77A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-13',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '17.5',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3900',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.94365',
#    'Delta 13 C (o/oo)': '-26.06943',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '138',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N78A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '40.2',
#    'Culmen Depth (mm)': '20.1',
#    'Flipper Length (mm)': '200',
#    'Body Mass (g)': '3975',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.95998',
#    'Delta 13 C (o/oo)': '-26.32601',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '140',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N79A2',
#    'Clutch Completion': 'No',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '39.7',
#    'Culmen Depth (mm)': '17.9',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '4250',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.25769',
#    'Delta 13 C (o/oo)': '-25.88798',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0910',
#    'Sample Number': '142',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N80A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-14',
#    'Culmen Length (mm)': '40.6',
#    'Culmen Depth (mm)': '17.2',
#    'Flipper Length (mm)': '187',
#    'Body Mass (g)': '3475',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.23408',
#    'Delta 13 C (o/oo)': '-26.01549',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '144',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N81A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '40.7',
#    'Culmen Depth (mm)': '17.0',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3725',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.05674',
#    'Delta 13 C (o/oo)': '-25.79529',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '146',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N82A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '39.0',
#    'Culmen Depth (mm)': '18.7',
#    'Flipper Length (mm)': '185',
#    'Body Mass (g)': '3650',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.22033',
#    'Delta 13 C (o/oo)': '-26.03442',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '147',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N83A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-13',
#    'Culmen Length (mm)': '39.2',
#    'Culmen Depth (mm)': '18.6',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '4250',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '9.11006',
#    'Delta 13 C (o/oo)': '-25.79549',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '150',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N84A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '37.8',
#    'Culmen Depth (mm)': '18.1',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3750',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.97533',
#    'Delta 13 C (o/oo)': '-26.03495',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '152',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N85A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '41.5',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '201',
#    'Body Mass (g)': '4000',
#    'Sex': 'MALE',
#    'Delta 15 N (o/oo)': '8.89640',
#    'Delta 13 C (o/oo)': '-26.06967',
#    'Comments': ''}],
#  'FEMALE': [{'studyName': 'PAL0708',
#    'Sample Number': '2',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N1A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-11',
#    'Culmen Length (mm)': '39.5',
#    'Culmen Depth (mm)': '17.4',
#    'Flipper Length (mm)': '186',
#    'Body Mass (g)': '3800',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.94956',
#    'Delta 13 C (o/oo)': '-24.69454',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '3',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N2A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '40.3',
#    'Culmen Depth (mm)': '18.0',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '3250',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.36821',
#    'Delta 13 C (o/oo)': '-25.33302',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '5',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N3A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '36.7',
#    'Culmen Depth (mm)': '19.3',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3450',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.76651',
#    'Delta 13 C (o/oo)': '-25.32426',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '7',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N4A1',
#    'Clutch Completion': 'No',
#    'Date Egg': '2007-11-15',
#    'Culmen Length (mm)': '38.9',
#    'Culmen Depth (mm)': '17.8',
#    'Flipper Length (mm)': '181',
#    'Body Mass (g)': '3625',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.18718',
#    'Delta 13 C (o/oo)': '-25.21799',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '13',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N7A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-15',
#    'Culmen Length (mm)': '41.1',
#    'Culmen Depth (mm)': '17.6',
#    'Flipper Length (mm)': '182',
#    'Body Mass (g)': '3200',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '16',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N8A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '36.6',
#    'Culmen Depth (mm)': '17.8',
#    'Flipper Length (mm)': '185',
#    'Body Mass (g)': '3700',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Not enough blood for isotopes.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '17',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N9A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '38.7',
#    'Culmen Depth (mm)': '19.0',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '3450',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.18528',
#    'Delta 13 C (o/oo)': '-25.06691',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '19',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N10A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '34.4',
#    'Culmen Depth (mm)': '18.4',
#    'Flipper Length (mm)': '184',
#    'Body Mass (g)': '3325',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.47827',
#    'Delta 13 C (o/oo)': '-25.23319',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '21',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N11A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '37.8',
#    'Culmen Depth (mm)': '18.3',
#    'Flipper Length (mm)': '174',
#    'Body Mass (g)': '3400',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.73762',
#    'Delta 13 C (o/oo)': '-25.09383',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '23',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N12A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '35.9',
#    'Culmen Depth (mm)': '19.2',
#    'Flipper Length (mm)': '189',
#    'Body Mass (g)': '3800',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.22286',
#    'Delta 13 C (o/oo)': '-25.03474',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '26',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N13A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-10',
#    'Culmen Length (mm)': '35.3',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '187',
#    'Body Mass (g)': '3800',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.21292',
#    'Delta 13 C (o/oo)': '-24.36130',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '28',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N17A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-12',
#    'Culmen Length (mm)': '40.5',
#    'Culmen Depth (mm)': '17.9',
#    'Flipper Length (mm)': '187',
#    'Body Mass (g)': '3200',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.08138',
#    'Delta 13 C (o/oo)': '-25.49448',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '29',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N18A1',
#    'Clutch Completion': 'No',
#    'Date Egg': '2007-11-10',
#    'Culmen Length (mm)': '37.9',
#    'Culmen Depth (mm)': '18.6',
#    'Flipper Length (mm)': '172',
#    'Body Mass (g)': '3150',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.38404',
#    'Delta 13 C (o/oo)': '-25.19837',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '31',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N21A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '39.5',
#    'Culmen Depth (mm)': '16.7',
#    'Flipper Length (mm)': '178',
#    'Body Mass (g)': '3250',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.69756',
#    'Delta 13 C (o/oo)': '-25.11223',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '33',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N22A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '39.5',
#    'Culmen Depth (mm)': '17.8',
#    'Flipper Length (mm)': '188',
#    'Body Mass (g)': '3300',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.66523',
#    'Delta 13 C (o/oo)': '-25.06020',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '35',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N23A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '36.4',
#    'Culmen Depth (mm)': '17.0',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '3325',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.17847',
#    'Delta 13 C (o/oo)': '-25.23061',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '38',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N24A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '42.2',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '180',
#    'Body Mass (g)': '3550',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.04787',
#    'Delta 13 C (o/oo)': '-25.49523',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '39',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N25A1',
#    'Clutch Completion': 'No',
#    'Date Egg': '2007-11-13',
#    'Culmen Length (mm)': '37.6',
#    'Culmen Depth (mm)': '19.3',
#    'Flipper Length (mm)': '181',
#    'Body Mass (g)': '3300',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.41131',
#    'Delta 13 C (o/oo)': '-25.04169',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '41',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N26A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '36.5',
#    'Culmen Depth (mm)': '18.0',
#    'Flipper Length (mm)': '182',
#    'Body Mass (g)': '3150',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.68933',
#    'Delta 13 C (o/oo)': '-24.42280',
#    'Comments': ''},
#   {'studyName': 'PAL0708',
#    'Sample Number': '43',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N27A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-19',
#    'Culmen Length (mm)': '36.0',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '186',
#    'Body Mass (g)': '3100',
# ...
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N49A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '37.7',
#    'Culmen Depth (mm)': '16.0',
#    'Flipper Length (mm)': '183',
#    'Body Mass (g)': '3075',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.21510',
#    'Delta 13 C (o/oo)': '-26.22530',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '105',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N51A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '37.9',
#    'Culmen Depth (mm)': '18.6',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '2925',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.02642',
#    'Delta 13 C (o/oo)': '-25.86482',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '107',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N53A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '38.6',
#    'Culmen Depth (mm)': '17.2',
#    'Flipper Length (mm)': '199',
#    'Body Mass (g)': '3750',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.77322',
#    'Delta 13 C (o/oo)': '-26.48973',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '109',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N55A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-20',
#    'Culmen Length (mm)': '38.1',
#    'Culmen Depth (mm)': '17.0',
#    'Flipper Length (mm)': '181',
#    'Body Mass (g)': '3175',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.79532',
#    'Delta 13 C (o/oo)': '-25.27385',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '111',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N58A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-12',
#    'Culmen Length (mm)': '38.1',
#    'Culmen Depth (mm)': '16.5',
#    'Flipper Length (mm)': '198',
#    'Body Mass (g)': '3825',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.43951',
#    'Delta 13 C (o/oo)': '-26.57563',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '113',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N60A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-15',
#    'Culmen Length (mm)': '39.7',
#    'Culmen Depth (mm)': '17.7',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3200',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.02657',
#    'Delta 13 C (o/oo)': '-26.06203',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '115',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Biscoe',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N61A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '39.6',
#    'Culmen Depth (mm)': '20.7',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '3900',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.80967',
#    'Delta 13 C (o/oo)': '-26.78958',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '117',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N63A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-18',
#    'Culmen Length (mm)': '38.6',
#    'Culmen Depth (mm)': '17.0',
#    'Flipper Length (mm)': '188',
#    'Body Mass (g)': '2900',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.18021',
#    'Delta 13 C (o/oo)': '-25.77264',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '119',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N64A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-22',
#    'Culmen Length (mm)': '35.7',
#    'Culmen Depth (mm)': '17.0',
#    'Flipper Length (mm)': '189',
#    'Body Mass (g)': '3350',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.96436',
#    'Delta 13 C (o/oo)': '-23.90309',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '121',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N66A1',
#    'Clutch Completion': 'No',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '36.2',
#    'Culmen Depth (mm)': '17.2',
#    'Flipper Length (mm)': '187',
#    'Body Mass (g)': '3150',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.04296',
#    'Delta 13 C (o/oo)': '-26.19444',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0910',
#    'Sample Number': '123',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N67A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '40.2',
#    'Culmen Depth (mm)': '17.0',
#    'Flipper Length (mm)': '176',
#    'Body Mass (g)': '3450',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.30722',
#    'Delta 13 C (o/oo)': '-25.61039',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '125',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N69A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-18',
#    'Culmen Length (mm)': '35.2',
#    'Culmen Depth (mm)': '15.9',
#    'Flipper Length (mm)': '186',
#    'Body Mass (g)': '3050',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.81668',
#    'Delta 13 C (o/oo)': '-25.95399',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '127',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N71A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-21',
#    'Culmen Length (mm)': '38.8',
#    'Culmen Depth (mm)': '17.6',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '3275',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.88098',
#    'Delta 13 C (o/oo)': '-25.89741',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '129',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N72A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-18',
#    'Culmen Length (mm)': '39.0',
#    'Culmen Depth (mm)': '17.1',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '3050',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.19031',
#    'Delta 13 C (o/oo)': '-25.73722',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '131',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N73A1',
#    'Clutch Completion': 'No',
#    'Date Egg': '2009-11-23',
#    'Culmen Length (mm)': '38.5',
#    'Culmen Depth (mm)': '17.9',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '3325',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.98460',
#    'Delta 13 C (o/oo)': '-25.57956',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0910',
#    'Sample Number': '133',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N76A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-10',
#    'Culmen Length (mm)': '36.8',
#    'Culmen Depth (mm)': '18.5',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3500',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.98705',
#    'Delta 13 C (o/oo)': '-25.57647',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '135',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N77A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-13',
#    'Culmen Length (mm)': '38.1',
#    'Culmen Depth (mm)': '17.6',
#    'Flipper Length (mm)': '187',
#    'Body Mass (g)': '3425',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.71700',
#    'Delta 13 C (o/oo)': '-25.77951',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '137',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N78A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '35.6',
#    'Culmen Depth (mm)': '17.5',
#    'Flipper Length (mm)': '191',
#    'Body Mass (g)': '3175',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.75984',
#    'Delta 13 C (o/oo)': '-25.97696',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '139',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N79A1',
#    'Clutch Completion': 'No',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '37.0',
#    'Culmen Depth (mm)': '16.5',
#    'Flipper Length (mm)': '185',
#    'Body Mass (g)': '3400',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.61651',
#    'Delta 13 C (o/oo)': '-26.07021',
#    'Comments': 'Nest never observed with full clutch.'},
#   {'studyName': 'PAL0910',
#    'Sample Number': '141',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N80A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-14',
#    'Culmen Length (mm)': '40.2',
#    'Culmen Depth (mm)': '17.1',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3400',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.28810',
#    'Delta 13 C (o/oo)': '-25.54976',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '143',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N81A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '32.1',
#    'Culmen Depth (mm)': '15.5',
#    'Flipper Length (mm)': '188',
#    'Body Mass (g)': '3050',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.79787',
#    'Delta 13 C (o/oo)': '-26.61075',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '145',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N82A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-16',
#    'Culmen Length (mm)': '37.3',
#    'Culmen Depth (mm)': '16.8',
#    'Flipper Length (mm)': '192',
#    'Body Mass (g)': '3000',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '9.06829',
#    'Delta 13 C (o/oo)': '-25.85203',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '148',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N83A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-13',
#    'Culmen Length (mm)': '36.6',
#    'Culmen Depth (mm)': '18.4',
#    'Flipper Length (mm)': '184',
#    'Body Mass (g)': '3475',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.68744',
#    'Delta 13 C (o/oo)': '-25.83060',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '149',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N84A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '36.0',
#    'Culmen Depth (mm)': '17.8',
#    'Flipper Length (mm)': '195',
#    'Body Mass (g)': '3450',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.94332',
#    'Delta 13 C (o/oo)': '-25.79189',
#    'Comments': ''},
#   {'studyName': 'PAL0910',
#    'Sample Number': '151',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N85A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2009-11-17',
#    'Culmen Length (mm)': '36.0',
#    'Culmen Depth (mm)': '17.1',
#    'Flipper Length (mm)': '187',
#    'Body Mass (g)': '3700',
#    'Sex': 'FEMALE',
#    'Delta 15 N (o/oo)': '8.93465',
#    'Delta 13 C (o/oo)': '-26.07081',
#    'Comments': ''}],
#  '': [{'studyName': 'PAL0708',
#    'Sample Number': '4',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N2A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-16',
#    'Culmen Length (mm)': '',
#    'Culmen Depth (mm)': '',
#    'Flipper Length (mm)': '',
#    'Body Mass (g)': '',
#    'Sex': '',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Adult not sampled.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '9',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N5A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '34.1',
#    'Culmen Depth (mm)': '18.1',
#    'Flipper Length (mm)': '193',
#    'Body Mass (g)': '3475',
#    'Sex': '',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'No blood sample obtained.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '10',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N5A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '42.0',
#    'Culmen Depth (mm)': '20.2',
#    'Flipper Length (mm)': '190',
#    'Body Mass (g)': '4250',
#    'Sex': '',
#    'Delta 15 N (o/oo)': '9.13362',
#    'Delta 13 C (o/oo)': '-25.09368',
#    'Comments': 'No blood sample obtained for sexing.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '11',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N6A1',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '37.8',
#    'Culmen Depth (mm)': '17.1',
#    'Flipper Length (mm)': '186',
#    'Body Mass (g)': '3300',
#    'Sex': '',
#    'Delta 15 N (o/oo)': '8.63243',
#    'Delta 13 C (o/oo)': '-25.21315',
#    'Comments': 'No blood sample obtained for sexing.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '12',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Torgersen',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N6A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-09',
#    'Culmen Length (mm)': '37.8',
#    'Culmen Depth (mm)': '17.3',
#    'Flipper Length (mm)': '180',
#    'Body Mass (g)': '3700',
#    'Sex': '',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'No blood sample obtained.'},
#   {'studyName': 'PAL0708',
#    'Sample Number': '48',
#    'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#    'Region': 'Anvers',
#    'Island': 'Dream',
#    'Stage': 'Adult, 1 Egg Stage',
#    'Individual ID': 'N29A2',
#    'Clutch Completion': 'Yes',
#    'Date Egg': '2007-11-13',
#    'Culmen Length (mm)': '37.5',
#    'Culmen Depth (mm)': '18.9',
#    'Flipper Length (mm)': '179',
#    'Body Mass (g)': '2975',
#    'Sex': '',
#    'Delta 15 N (o/oo)': '',
#    'Delta 13 C (o/oo)': '',
#    'Comments': 'Sexing primers did not amplify. Not enough blood for isotopes.'}]}

# %%
len(data_by_sex)
# Out:
# 3

# %%
data_by_sex.keys()
# Out:
# dict_keys(['MALE', 'FEMALE', ''])

# %%
for (sex, sex_rows) in data_by_sex.items():
    print(sex, len(sex_rows))
# Out:
# MALE 73
# FEMALE 73
#  6

# %%
data[0]
# Out:
# {'studyName': 'PAL0708',
#  'Sample Number': '1',
#  'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#  'Region': 'Anvers',
#  'Island': 'Torgersen',
#  'Stage': 'Adult, 1 Egg Stage',
#  'Individual ID': 'N1A1',
#  'Clutch Completion': 'Yes',
#  'Date Egg': '2007-11-11',
#  'Culmen Length (mm)': '39.1',
#  'Culmen Depth (mm)': '18.7',
#  'Flipper Length (mm)': '181',
#  'Body Mass (g)': '3750',
#  'Sex': 'MALE',
#  'Delta 15 N (o/oo)': '',
#  'Delta 13 C (o/oo)': '',
#  'Comments': 'Not enough blood for isotopes.'}

# %%
data[0]["test"] = True

# %%
data_by_sex["MALE"][0]
# Out:
# {'studyName': 'PAL0708',
#  'Sample Number': '1',
#  'Species': 'Adelie Penguin (Pygoscelis adeliae)',
#  'Region': 'Anvers',
#  'Island': 'Torgersen',
#  'Stage': 'Adult, 1 Egg Stage',
#  'Individual ID': 'N1A1',
#  'Clutch Completion': 'Yes',
#  'Date Egg': '2007-11-11',
#  'Culmen Length (mm)': '39.1',
#  'Culmen Depth (mm)': '18.7',
#  'Flipper Length (mm)': '181',
#  'Body Mass (g)': '3750',
#  'Sex': 'MALE',
#  'Delta 15 N (o/oo)': '',
#  'Delta 13 C (o/oo)': '',
#  'Comments': 'Not enough blood for isotopes.',
#  'test': True}
