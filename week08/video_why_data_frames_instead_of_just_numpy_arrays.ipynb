# %% [markdown]
# # Video: Why Data Frames instead of Just NumPy Arrays?
#
# This video explains the advantages of data frames over just using NumPy arrays.

# %% [markdown]
# ## Why Data Frames?
#
# Structure, structure, structure
# * Column names
# * Column types
# * Manipulability

# %% [markdown]
# ## Code Example: Inspecting Abalone Data

# %%
import pandas as pd
abalone = pd.read_csv("https://raw.githubusercontent.com/bu-cds-omds/dx602-examples/main/data/abalone.tsv", sep="\t")

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
abalone.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
abalone['Length']
# Out:
# 0       0.455
# 1       0.350
# 2       0.530
# 3       0.440
# 4       0.330
#         ...
# 4172    0.565
# 4173    0.590
# 4174    0.600
# 4175    0.625
# 4176    0.710
# Name: Length, Length: 4177, dtype: float64

# %%
abalone['Sex']
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: Sex, Length: 4177, dtype: object

# %%
abalone[abalone['Sex'] == 'M']
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 11     M   0.430     0.350   0.110        0.4060          0.1675
# ...   ..     ...       ...     ...           ...             ...
# 4170   M   0.550     0.430   0.130        0.8395          0.3155
# 4171   M   0.560     0.430   0.155        0.8675          0.4000
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 3             0.1140        0.1550     10
# 8             0.1125        0.1650      9
# 11            0.0810        0.1350     10
# ...              ...           ...    ...
# 4170          0.1955        0.2405     10
# 4171          0.1720        0.2290      8
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4176          0.3765        0.4950     12
#
# [1528 rows x 9 columns]

# %%
abalone.query("Sex == 'M'")
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 11     M   0.430     0.350   0.110        0.4060          0.1675
# ...   ..     ...       ...     ...           ...             ...
# 4170   M   0.550     0.430   0.130        0.8395          0.3155
# 4171   M   0.560     0.430   0.155        0.8675          0.4000
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 3             0.1140        0.1550     10
# 8             0.1125        0.1650      9
# 11            0.0810        0.1350     10
# ...              ...           ...    ...
# 4170          0.1955        0.2405     10
# 4171          0.1720        0.2290      8
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4176          0.3765        0.4950     12
#
# [1528 rows x 9 columns]

# %%
abalone.query("Sex == 'M' and (Diameter < 0.4 or Rings > 15)")
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 11     M   0.430     0.350   0.110        0.4060          0.1675
# ...   ..     ...       ...     ...           ...             ...
# 4156   M   0.475     0.370   0.110        0.4895          0.2185
# 4157   M   0.475     0.360   0.140        0.5135          0.2410
# 4162   M   0.385     0.255   0.100        0.3175          0.1370
# 4167   M   0.500     0.380   0.125        0.5770          0.2690
# 4169   M   0.520     0.385   0.165        0.7910          0.3750
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 3             0.1140        0.1550     10
# 8             0.1125        0.1650      9
# 11            0.0810        0.1350     10
# ...              ...           ...    ...
# 4156          0.1070        0.1460      8
# 4157          0.1045        0.1550      8
# 4162          0.0680        0.0920      8
# 4167          0.1265        0.1535      9
# 4169          0.1800        0.1815     10
#
# [498 rows x 9 columns]

# %%
abalone.groupby("Sex").mean()
# Out:
#        Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Sex
# F    0.579093  0.454732  0.158011      1.046532        0.446188
# I    0.427746  0.326494  0.107996      0.431363        0.191035
# M    0.561391  0.439287  0.151381      0.991459        0.432946
#
#      Viscera_weight  Shell_weight      Rings
# Sex
# F          0.230689      0.302010  11.129304
# I          0.092010      0.128182   7.890462
# M          0.215545      0.281969  10.705497

# %%
abalone.corr(numeric_only=True)
# Out:
#                   Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole_weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked_weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera_weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell_weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera_weight  Shell_weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole_weight          0.966375      0.955355  0.540390
# Shucked_weight        0.931961      0.882617  0.420884
# Viscera_weight        1.000000      0.907656  0.503819
# Shell_weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %% [markdown]
# * The next one blew my mind when I first saw it.

# %%
_ = pd.plotting.scatter_matrix(abalone, alpha=0.2)

# %% [markdown]
# ## There is Value in Making Software Easier to Write
#
# * Easy things are done a lot more than hard things
# * The history of software development is full of examples of making hard things easier, so more things can become possible.

# %%
abalone.corr(numeric_only=True)
# Out:
#                   Length  Diameter    Height  Whole_weight  Shucked_weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole_weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked_weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera_weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell_weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera_weight  Shell_weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole_weight          0.966375      0.955355  0.540390
# Shucked_weight        0.931961      0.882617  0.420884
# Viscera_weight        1.000000      0.907656  0.503819
# Shell_weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %% [markdown]
# ## Column names are much better than column indices
#
# * Column names help you write more maintainable and robust code.
# * Is it ok for your program to break if a file has columns in a different order?
# * Is it ok to introduce bugs if a column is added anywhere but the end?

# %% [markdown]
# ## Column Names Support Higher Level Patterns
#
# Starts with your code "knowing" what data you have...
# * Writing queries vs individual operations
# * Write what to do -> write what you want
# * Looking forward: AI will be helping here.

# %%
abalone['Length'].plot(kind='hist', bins=20, title='My Length Chart')
# Out:
# <Axes: title={'center': 'My Length Chart'}, ylabel='Frequency'>
